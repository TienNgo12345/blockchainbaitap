# %% [markdown]
# <a href="https://colab.research.google.com/github/TienNgo12345/blockchainbaitap/blob/main/cau1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !echo "anh tien dep trai" > plaintext.txt

# %%
# !openssl enc -aes-256-cbc -salt -pbkdf2 -in plaintext.txt -out encrypted.bin
# Out:
# enter AES-256-CBC encryption password:
# Verifying - enter AES-256-CBC encryption password:

# %%
# !openssl enc -aes-256-cbc -salt -pbkdf2 -in plaintext.txt -out encrypted.bin -pass pass:123456

# %%
# !openssl enc -d -aes-256-cbc -salt -pbkdf2 -in encrypted.bin -out decrypted.txt -pass pass:123456
# !cat decrypted.txt
# Out:
# anh tien dep trai
