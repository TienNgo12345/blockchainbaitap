# %% [markdown]
# <a href="https://colab.research.google.com/github/TienNgo12345/blockchainbaitap/blob/main/cau3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !openssl dgst -sha256 -sign private_key.pem -out signature.bin plaintext.txt

# %%
# !openssl dgst -sha256 -verify public_key.pem -signature signature.bin plaintext.txt
# Out:
# Verified OK
